# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (0.5.13)
# Requirement already satisfied: build>=1.0.3 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.115.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.31.1)
# Requirement already satisfied: numpy>=1.22.5 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.16.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.20.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (1.66.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: packaging>=19.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.41.0,>=0.37.2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.40.0)
# Requirement already satisfied: anyio in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: sniffio in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Requirement already satisfied: requests-oauthlib in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: durationpy>=0.7 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.25.2)
# Requirement already satisfied: click>=8.0.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.2)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/admin/MY/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
import chromadb
client=chromadb.Client()
collection=client.create_collection(name="my_collection")

# %%
collection.add(
   documents=[
       "This document is about New York",
       "This document is about Delhi"
  ],
    ids=['id1','id2']
)
# Out:
# /Users/admin/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█| 79.

# %%
all_docs=collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'metadatas': [None, None],
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents']}

# %%
documents=collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'metadatas': [None],
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents']}

# %%
results=collection.query(
    query_texts=['Query is about Chhole Bhature'],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'distances': [[1.5588479042053223, 1.8114912509918213]],
#  'metadatas': [[None, None]],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
results=collection.query(
    query_texts=['Query is about Big Apple'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'distances': [[1.6312179565429688, 1.867558479309082]],
#  'metadatas': [[None, None]],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
results=collection.query(
    query_texts=['Query is about Brooklyn bridge'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'distances': [[1.0953426361083984, 1.571173071861267]],
#  'metadatas': [[None, None]],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
results=collection.query(
    query_texts=['Query is about Air pollution'],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'distances': [[1.5176870822906494, 1.6557271480560303]],
#  'metadatas': [[None, None]],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}
